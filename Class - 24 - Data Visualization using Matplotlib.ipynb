# %% [markdown]
# # Data Visualization using Matplotlib

# %% [markdown]
# Data Visualization is an important part of business activities as organizations nowadays collect a huge amount of data. Sensors all over the world are collecting climate data, user data through clicks, car data for prediction of steening wheels etc. all of these data collected hold key insights for businesses and visualizations make these insights easy to interpret. Data is only as good as it’s presented. Visulizations are the easiest way to analyze and absorb information. Visuals help to easily understand the complex problem. They help in identifying patterns, relationships, and outliers in data. It helps in understanding business problems better and quickly. It helps to build a compelling story based on visuals.
# Matplotlib Matplotlib is a 2-D plotting library that helps in visualizing figures. Matplotlib emulates Matlab like graphs and visualizations.
# Matplolib has a module called pyplot which aids in plotting figure. The Jupyter notebook is used for running the plots. We import matplotlib.pyplot as plt for making it call the package module.
# Importing required libraries and dataset to plot using Pandas pd.read_csv()
# Extracting important parts for plots using conditions on Pandas Dataframes.
# plt.plot()for plotting line chart similarly in place of plot other functions are used for plotting. All plotting. All plotting functions require data and it is provided in the function through parameters. plot.xlabel, plt ylabel for labeling x and y-axis respectively.

# %%
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array([1,2,3,4,5,6,7])
b=np.array([1,2,3,4,5,6,7])

# %%
plt.title("Linear Line")
plt.xlabel("a")
plt.ylabel("b")
plt.plot(a,b)
plt.show()

# %%
g=np.array([3,6,44,12,67,45,55])
h=np.array([22,4,5,6,78,22,12])

# %%
plt.xlabel('g')
plt.ylabel('h')
plt.plot(g,h)
plt.show()

# %%
plt.plot(g,h,'--g')
plt.show()

# %%
x = [5,8,10,2,6,12]
y = [12,16,6,10,14,6]

# %%
plt.bar(x,y)
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.bar(x, y, color = 'g', align = 'center') #(color – g - green)
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# A histogram takes in a series of data and divides the data into a number of bins. It then plots the frequency data points in each bin (i.e. the interval of points). It is useful in understanding the count of data ranges. When to use: We should use histogram when we need the count of the variable in a plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a, bins = [0,20,40,60,80,100])
plt.title("histogram")
plt.show()

# %%
#https://github.com/dsrscientist/dataset1/blob/master/student_marks.csv
import pandas as pd
df=pd.read_csv('student_marks.csv')
print(df)
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %% [markdown]
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English', 'Biology', 'Economics', 'History', 'Civics'], dtype='object')

# %%
plt.hist(df['Maths'], bins=10)
plt.title('Maths Histogram')
plt.show()

# %%
plt.hist(df['English'], bins=10)
plt.title('English')
plt.show()

# %%
#Boxplot
plt.boxplot(df['Maths'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2854df0c910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2854df0c670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2854dfe2b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2854df0c490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2854df0c190>],
#  'means': []}

# %%
plt.boxplot(df['Chemistry'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x285515cc070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x285515cc610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x285515edd60>],
#  'medians': [<matplotlib.lines.Line2D at 0x285515ccbb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x285515cceb0>],
#  'means': []}

# %%
plt.violinplot(df['Maths'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x28551653460>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x285516533d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x28551653b20>,
#  'cbars': <matplotlib.collections.LineCollection at 0x28551653ee0>}

# %%
plt.violinplot(df['Chemistry'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x285516954c0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2855169b5e0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2855169bc10>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2855169bfd0>}

# %%
x=np.array([3,6,44,12,67,45,55])
y=np.array([22,4,5,6,78,22,12])

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y)
plt.show()

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
b=np.array([24,88,51,23,46,77,56,34,21,80,11,58,29,21,97])

# %%
plt.title("scatter plot")
plt.xlabel('a')
plt.ylabel('b')
plt.scatter(a,b)
plt.show()

# %%
x=df['Maths']
y=df['English']
plt.scatter(x,y)
plt.xlabel('Maths')
plt.ylabel('English')
plt.show()

# %%
Matplotlib OVER

# %% [markdown]
# # Seaborn visualization library

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')
x=['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday']
y=[4,5,6,7,8]
sns.stripplot(x,y)
# Out:
# <AxesSubplot:>

# %%
#Load the data
ds=pd.read_csv('emptest.csv')
print(ds)
print(ds.head())
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
#Create violinplot
sns.violinplot(x = "Salary", data=ds)
#Show the plot
plt.show()

# %%
sns.violinplot(x = "Age", data=ds)
# Out:
# <AxesSubplot:xlabel='Age'>
